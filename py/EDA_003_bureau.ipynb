# %%
import pandas as pd
import numpy as np
from glob import glob
from IPython.display import display
pd.set_option('display.max_columns', 99)
pd.set_option('display.max_rows', 99)
import EDA
import utils
sorted(glob('../data/*'))
# Out:
# ['../data/101_test',
#  '../data/101_train',
#  '../data/102-1_test',
#  '../data/102-1_test_filtered',
#  '../data/102-1_train',
#  '../data/102-1_train_filtered',
#  '../data/102-2_test',
#  '../data/102-2_test_filtered',
#  '../data/102-2_train',
#  '../data/102-2_train_filtered',
#  '../data/102-3_CHANNEL_TYPE_test',
#  '../data/102-3_CHANNEL_TYPE_test_filtered',
#  '../data/102-3_CHANNEL_TYPE_train',
#  '../data/102-3_CHANNEL_TYPE_train_filtered',
#  '../data/102-3_CODE_REJECT_REASON_test',
#  '../data/102-3_CODE_REJECT_REASON_test_filtered',
#  '../data/102-3_CODE_REJECT_REASON_train',
#  '../data/102-3_CODE_REJECT_REASON_train_filtered',
#  '../data/102-3_NAME_CASH_LOAN_PURPOSE_test',
#  '../data/102-3_NAME_CASH_LOAN_PURPOSE_test_filtered',
#  '../data/102-3_NAME_CASH_LOAN_PURPOSE_train',
#  '../data/102-3_NAME_CASH_LOAN_PURPOSE_train_filtered',
#  '../data/102-3_NAME_CLIENT_TYPE_test',
#  '../data/102-3_NAME_CLIENT_TYPE_test_filtered',
# ...

# %%
df = utils.read_pickles('../data/bureau').sort_values(['SK_ID_CURR', 'DAYS_CREDIT'], ascending=[True, False])
df.head()
# Out:
# 100%|██████████| 20/20 [00:02<00:00,  8.86it/s]
#         SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 248489      100001       5896635        Active      currency 1          -49
# 248490      100001       5896636        Active      currency 1         -320
# 248488      100001       5896634        Active      currency 1         -559
# 248484      100001       5896630        Closed      currency 1         -857
# 248486      100001       5896632        Closed      currency 1         -879
#
#         CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 248489                   0               1778.0                NaN
# 248490                   0                411.0                NaN
# 248488                   0                902.0                NaN
# 248484                   0               -492.0             -553.0
# 248486                   0               -514.0             -544.0
#
# ...

# %%
EDA.df_info(df)
# Out:
# Shape: (1716428, 17)
#                        DataType   #Nulls  #Uniques          Min          Mean  \
# SK_ID_CURR                int64        0    305811   100001.000  2.782149e+05
# SK_ID_BUREAU              int64        0   1716428  5000000.000  5.924434e+06
# CREDIT_ACTIVE            object        0         4          NaN           NaN
# CREDIT_CURRENCY          object        0         4          NaN           NaN
# DAYS_CREDIT               int64        0      2923    -2922.000 -1.142108e+03
# CREDIT_DAY_OVERDUE        int64        0       942        0.000  8.181666e-01
# DAYS_CREDIT_ENDDATE     float64   105553     14096   -42060.000  5.105174e+02
# DAYS_ENDDATE_FACT       float64   633653      2917   -42023.000 -1.017437e+03
# AMT_CREDIT_MAX_OVERDUE  float64  1124488     68251        0.000  3.825418e+03
# CNT_CREDIT_PROLONG        int64        0        10        0.000  6.410406e-03
# AMT_CREDIT_SUM          float64       13    236708        0.000  3.549946e+05
# ...

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'SK_ID_BUREAU', 'CREDIT_ACTIVE', 'CREDIT_CURRENCY',
#        'DAYS_CREDIT', 'CREDIT_DAY_OVERDUE', 'DAYS_CREDIT_ENDDATE',
#        'DAYS_ENDDATE_FACT', 'AMT_CREDIT_MAX_OVERDUE', 'CNT_CREDIT_PROLONG',
#        'AMT_CREDIT_SUM', 'AMT_CREDIT_SUM_DEBT', 'AMT_CREDIT_SUM_LIMIT',
#        'AMT_CREDIT_SUM_OVERDUE', 'CREDIT_TYPE', 'DAYS_CREDIT_UPDATE',
#        'AMT_ANNUITY'],
#       dtype='object')

# %%
ids = df.SK_ID_CURR.unique()

# %%
tmp = df[df.SK_ID_CURR.isin(np.random.choice(ids, size=9))]
tmp
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 926882       130466       5120140        Closed      currency 1        -1365
# 926881       130466       5120139        Closed      currency 1        -1366
# 209041       147788       6576270        Closed      currency 1        -2629
# 209040       147788       6576269        Closed      currency 1        -2630
# 1463654      160118       5368069        Active      currency 1         -180
# 1463652      160118       5368067        Active      currency 1         -421
# 1463651      160118       5368066        Active      currency 1         -657
# 777643       160118       5368065        Closed      currency 1        -1009
# 1463653      160118       5368068        Closed      currency 1        -1198
# 1007441      166060       5123253        Active      currency 1         -259
# 1007444      166060       5123256        Active      currency 1         -660
# ...

# %%
tmp.to_csv('bure_sample.csv', index=False)
