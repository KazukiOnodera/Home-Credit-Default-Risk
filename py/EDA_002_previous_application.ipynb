# %%
import pandas as pd
import numpy as np
from glob import glob
from IPython.display import display
pd.set_option('display.max_columns', 99)
pd.set_option('display.max_rows', 99)
import EDA
import utils
#sorted(glob('../data/*'))

# %%
df = utils.read_pickles('../data/previous_application').sort_values(['SK_ID_CURR', 'DAYS_DECISION'], ascending=[True, False])
df.head()
# Out:
# 100%|██████████| 20/20 [00:04<00:00,  4.45it/s]
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 201668      1369693      100001     Consumer loans     3951.000
# 892077      1038818      100002     Consumer loans     9251.775
# 575941      1810518      100003         Cash loans    98356.995
# 1021650     2636178      100003     Consumer loans    64567.665
# 1223745     2396755      100003     Consumer loans     6737.310
#
#          AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 201668           24835.5     23787.0            2520.0          24835.5
# 892077          179055.0    179055.0               0.0         179055.0
# 575941          900000.0   1035882.0               NaN         900000.0
# 1021650         337500.0    348637.5               0.0         337500.0
# 1223745          68809.5     68053.5            6885.0          68809.5
#
#         WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# ...

# %%
EDA.df_info(df)
# Out:
# Shape: (1670214, 37)
#                             DataType   #Nulls  #Uniques           Min  \
# SK_ID_PREV                     int64        0   1670214  1.000001e+06
# SK_ID_CURR                     int64        0    338857  1.000010e+05
# NAME_CONTRACT_TYPE            object        0         4           NaN
# AMT_ANNUITY                  float64   372235    357959  0.000000e+00
# AMT_APPLICATION              float64        0     93885  0.000000e+00
# AMT_CREDIT                   float64        1     86803  0.000000e+00
# AMT_DOWN_PAYMENT             float64   895844     29278 -9.000000e-01
# AMT_GOODS_PRICE              float64   385515     93885  0.000000e+00
# WEEKDAY_APPR_PROCESS_START    object        0         7           NaN
# HOUR_APPR_PROCESS_START        int64        0        24  0.000000e+00
# FLAG_LAST_APPL_PER_CONTRACT    int64        0         2  0.000000e+00
# NFLAG_LAST_APPL_IN_DAY         int64        0         2  0.000000e+00
# ...

# %%
ids = df.SK_ID_CURR.unique()

# %%
tmp = df[df.SK_ID_CURR==np.random.choice(ids)]
tmp
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 365920      1299385      233573    Revolving loans          NaN
# 1204654     2301069      233573     Consumer loans     6424.875
#
#          AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 365920               0.0         0.0               NaN              NaN
# 1204654          78070.5     90436.5               0.0          78070.5
#
#         WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# 365920                     TUESDAY                        9
# 1204654                   SATURDAY                       10
#
#          FLAG_LAST_APPL_PER_CONTRACT  NFLAG_LAST_APPL_IN_DAY  \
# 365920                             1                       1
# 1204654                            1                       1
#
#          RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  RATE_INTEREST_PRIVILEGED  \
# 365920                 NaN                    NaN                       NaN
# ...

# %%
tmp = df[df.SK_ID_CURR.isin(np.random.choice(ids, size=9))]
tmp
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 71327       2816415      140172    Revolving loans          NaN
# 1077305     2844537      140172         Cash loans          NaN
# 1095636     2071065      140172    Revolving loans    10125.000
# 559891      1887759      140172     Consumer loans     7936.200
# 1411986     2565884      140172     Consumer loans    13712.940
# 623924      1201303      144977     Consumer loans     4070.880
# 865889      1890382      144977     Consumer loans     4324.275
# 74706       1591892      174025    Revolving loans     2250.000
# 605851      1124055      174025    Revolving loans          NaN
# 678277      1593325      278032    Revolving loans     6750.000
# 949385      1821662      278032     Consumer loans     4199.895
# 1181779     2134576      278032     Consumer loans     6155.100
# 1247900     1623417      291356     Consumer loans    10332.000
# 663844      2800901      341498     Consumer loans    16766.280
# ...

# %%
tmp.to_csv('sample_pre.csv', index=False)

# %%
imp = pd.read_csv('LOG/imp_199_cv_filter.py.csv')

# %%
imp
# Out:
#                                                    index  split         gain
# 0          prev_NAME_YIELD_GROUP_DAYS_DECISION-high_mean     85  4567.900959
# 1                 prev_NAME_CONTRACT_STATUS_Refused_norm     83  4170.988615
# 2      prev_NAME_YIELD_GROUP_DAYS_LAST_DUE_1ST_VERSIO...     78  4084.240275
# 3                          prev_DL1-0PRODUCT_COMBINATION     73  3992.978409
# 4      prev_NAME_CONTRACT_STATUS_DAYS_DECISION-Refuse...     66  3476.701177
# 5      prev_NAME_YIELD_GROUP_DAYS_LAST_DUE_1ST_VERSIO...     74  3291.238058
# 6      prev_PRODUCT_COMBINATION_CNT_PAYMENT-Cash-X-Se...     84  2928.021604
# 7      prev_gby-SK_ID_CURR-CODE_REJECT_REASON_AMT_DOW...     45  2593.869161
# 8      prev_gby-SK_ID_CURR-CODE_REJECT_REASON_DAYS_FI...     35  2462.419233
# 9            prev_NAME_YIELD_GROUP_CNT_PAYMENT-high_mean     83  2416.010844
# 10                      prev_CODE_REJECT_REASON_XAP_norm     63  2413.962090
# ...
