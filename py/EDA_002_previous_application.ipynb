# %%
import pandas as pd
import numpy as np
from glob import glob
from IPython.display import display
pd.set_option('display.max_columns', 99)
pd.set_option('display.max_rows', 99)
import EDA
import utils
sorted(glob('../input/*'))
# Out:
# ['../input/HomeCredit_columns_description.csv',
#  '../input/POS_CASH_balance.csv.zip',
#  '../input/application_test.csv.zip',
#  '../input/application_train.csv.zip',
#  '../input/bureau.csv.zip',
#  '../input/bureau_balance.csv.zip',
#  '../input/credit_card_balance.csv.zip',
#  '../input/installments_payments.csv.zip',
#  '../input/previous_application.csv.zip',
#  '../input/sample_submission.csv.zip']

# %%
df = pd.read_csv('../input/previous_application.csv.zip')
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# ...

# %%
df.SELLERPLACE_AREA.min()
# Out:
# -1

# %%
df.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'AMT_ANNUITY',
#        'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'FLAG_LAST_APPL_PER_CONTRACT', 'NFLAG_LAST_APPL_IN_DAY',
#        'RATE_DOWN_PAYMENT', 'RATE_INTEREST_PRIMARY',
#        'RATE_INTEREST_PRIVILEGED', 'NAME_CASH_LOAN_PURPOSE',
#        'NAME_CONTRACT_STATUS', 'DAYS_DECISION', 'NAME_PAYMENT_TYPE',
#        'CODE_REJECT_REASON', 'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE',
#        'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE',
#        'CHANNEL_TYPE', 'SELLERPLACE_AREA', 'NAME_SELLER_INDUSTRY',
#        'CNT_PAYMENT', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION',
#        'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION',
#        'DAYS_LAST_DUE', 'DAYS_TERMINATION', 'NFLAG_INSURED_ON_APPROVAL'],
#       dtype='object')

# %%
[c for c in df.columns if df[c].dtype=='O']
# Out:
# ['NAME_CONTRACT_TYPE',
#  'WEEKDAY_APPR_PROCESS_START',
#  'FLAG_LAST_APPL_PER_CONTRACT',
#  'NAME_CASH_LOAN_PURPOSE',
#  'NAME_CONTRACT_STATUS',
#  'NAME_PAYMENT_TYPE',
#  'CODE_REJECT_REASON',
#  'NAME_TYPE_SUITE',
#  'NAME_CLIENT_TYPE',
#  'NAME_GOODS_CATEGORY',
#  'NAME_PORTFOLIO',
#  'NAME_PRODUCT_TYPE',
#  'CHANNEL_TYPE',
#  'NAME_SELLER_INDUSTRY',
#  'NAME_YIELD_GROUP',
#  'PRODUCT_COMBINATION']

# %%
EDA.df_info(df)
# Out:
# Shape: (1670214, 37)
#                             DataType   #Nulls  #Uniques
# SK_ID_PREV                     int64        0   1670214
# SK_ID_CURR                     int64        0    338857
# NAME_CONTRACT_TYPE            object        0         4
# AMT_ANNUITY                  float64   372235    357959
# AMT_APPLICATION              float64        0     93885
# AMT_CREDIT                   float64        1     86803
# AMT_DOWN_PAYMENT             float64   895844     29278
# AMT_GOODS_PRICE              float64   385515     93885
# WEEKDAY_APPR_PROCESS_START    object        0         7
# HOUR_APPR_PROCESS_START        int64        0        24
# FLAG_LAST_APPL_PER_CONTRACT   object        0         2
# NFLAG_LAST_APPL_IN_DAY         int64        0         2
# RATE_DOWN_PAYMENT            float64   895844    207033
# RATE_INTEREST_PRIMARY        float64  1664263       148
# RATE_INTEREST_PRIVILEGED     float64  1664263        25
# ...

# %%
df.sort_values(['SK_ID_CURR', 'SK_ID_PREV'], inplace=True)
df
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 201668      1369693      100001     Consumer loans     3951.000
# 892077      1038818      100002     Consumer loans     9251.775
# 575941      1810518      100003         Cash loans    98356.995
# 1223745     2396755      100003     Consumer loans     6737.310
# 1021650     2636178      100003     Consumer loans    64567.665
# 935548      1564014      100004     Consumer loans     5357.250
# 1259112     1857999      100005         Cash loans          NaN
# 1378978     2495675      100005     Consumer loans     4813.200
# 1131133     1020698      100006         Cash loans    39954.510
# 1232752     1243599      100006         Cash loans          NaN
# 900957      1489396      100006    Revolving loans    13500.000
# 1607443     1697039      100006         Cash loans    32696.100
# 98162       2078043      100006         Cash loans    24246.000
# 830967      2190416      100006     Consumer loans    29027.520
# ...

# %%
tmp = pd.crosstab(df['SK_ID_CURR'], df['NAME_CONTRACT_TYPE'])
tmp
# Out:
# NAME_CONTRACT_TYPE  Cash loans  Consumer loans  Revolving loans  XNA
# SK_ID_CURR
# 100001                       0               1                0    0
# 100002                       0               1                0    0
# 100003                       1               2                0    0
# 100004                       0               1                0    0
# 100005                       1               1                0    0
# 100006                       5               2                2    0
# 100007                       4               2                0    0
# 100008                       2               3                0    0
# 100009                       0               7                0    0
# 100010                       0               1                0    0
# 100011                       2               1                1    0
# 100012                       3               1                0    0
# ...

# %%
tmp.columns = ['prev_sum_'+c.replace(' ', '-') for c in tmp.columns]

# %%
tmp
# Out:
#             prev_sum_Cash-loans  prev_sum_Consumer-loans  \
# SK_ID_CURR
# 100001                        0                        1
# 100002                        0                        1
# 100003                        1                        2
# 100004                        0                        1
# 100005                        1                        1
# 100006                        5                        2
# 100007                        4                        2
# 100008                        2                        3
# 100009                        0                        7
# 100010                        0                        1
# 100011                        2                        1
# 100012                        3                        1
# 100013                        2                        2
# 100014                        0                        2
# 100015                        0                        1
# ...
