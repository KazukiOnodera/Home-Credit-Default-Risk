# %%
import pandas as pd
import numpy as np
from glob import glob
from IPython.display import display
pd.set_option('display.max_columns', 99)
pd.set_option('display.max_rows', 99)
import EDA
import utils
sorted(glob('../input/*'))
# Out:
# ['../input/HomeCredit_columns_description.csv',
#  '../input/POS_CASH_balance.csv.zip',
#  '../input/application_test.csv.zip',
#  '../input/application_train.csv.zip',
#  '../input/bureau.csv.zip',
#  '../input/bureau_balance.csv.zip',
#  '../input/credit_card_balance.csv.zip',
#  '../input/installments_payments.csv.zip',
#  '../input/previous_application.csv.zip',
#  '../input/sample_submission.csv.zip']

# %%
df = pd.read_csv('../input/bureau_balance.csv.zip')
df.head()
# Out:
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C
# 3       5715448              -3      C
# 4       5715448              -4      C

# %%
EDA.df_info(df)
# Out:
# Shape: (27299925, 3)
#                DataType  #Nulls  #Uniques
# SK_ID_BUREAU      int64       0    817395
# MONTHS_BALANCE    int64       0        97
# STATUS           object       0         8

# %%
df.sort_values(['SK_ID_BUREAU', 'MONTHS_BALANCE'], inplace=True)
df
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 26079849       5001709             -96      X
# 26079848       5001709             -95      X
# 26079847       5001709             -94      X
# 26079846       5001709             -93      X
# 26079845       5001709             -92      X
# 26079844       5001709             -91      X
# 26079843       5001709             -90      X
# 26079842       5001709             -89      X
# 26079841       5001709             -88      X
# 26079840       5001709             -87      X
# 26079839       5001709             -86      X
# 26079838       5001709             -85      C
# 26079837       5001709             -84      C
# 26079836       5001709             -83      C
# 26079835       5001709             -82      C
# 26079834       5001709             -81      C
# 26079833       5001709             -80      C
# 26079832       5001709             -79      C
# 26079831       5001709             -78      C
# ...

# %%
ids = df.SK_ID_BUREAU.unique()

# %%
df[df.SK_ID_BUREAU==np.random.choice(ids)]
# Out:
#          SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 9289569       6130888             -19      0
# 9289568       6130888             -18      0
# 9289567       6130888             -17      0
# 9289566       6130888             -16      0
# 9289565       6130888             -15      0
# 9289564       6130888             -14      0
# 9289563       6130888             -13      0
# 9289562       6130888             -12      0
# 9289561       6130888             -11      0
# 9289560       6130888             -10      0
# 9289559       6130888              -9      0
# 9289558       6130888              -8      0
# 9289557       6130888              -7      0
# 9289556       6130888              -6      0
# 9289555       6130888              -5      0
# 9289554       6130888              -4      0
# 9289553       6130888              -3      C
# 9289552       6130888              -2      C
# 9289551       6130888              -1      C
# 9289550       6130888               0      C
