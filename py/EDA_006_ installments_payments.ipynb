# %%
import pandas as pd
import numpy as np
from glob import glob
from IPython.display import display
pd.set_option('display.max_columns', 99)
pd.set_option('display.max_rows', 99)
import EDA
import utils
sorted(glob('../input/*'))
# Out:
# ['../input/HomeCredit_columns_description.csv',
#  '../input/POS_CASH_balance.csv.zip',
#  '../input/application_test.csv.zip',
#  '../input/application_train.csv.zip',
#  '../input/bureau.csv.zip',
#  '../input/bureau_balance.csv.zip',
#  '../input/credit_card_balance.csv.zip',
#  '../input/installments_payments.csv.zip',
#  '../input/previous_application.csv.zip',
#  '../input/sample_submission.csv.zip']

# %%
df = pd.read_csv('../input/installments_payments.csv.zip')
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0     1054186      161674                     1.0                      6
# 1     1330831      151639                     0.0                     34
# 2     2085231      193053                     2.0                      1
# 3     2452527      199697                     1.0                      3
# 4     2714724      167756                     1.0                      2
#
#    DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  AMT_INSTALMENT  AMT_PAYMENT
# 0          -1180.0             -1187.0        6948.360     6948.360
# 1          -2156.0             -2156.0        1716.525     1716.525
# 2            -63.0               -63.0       25425.000    25425.000
# 3          -2418.0             -2426.0       24350.130    24350.130
# 4          -1383.0             -1366.0        2165.040     2160.585

# %%
EDA.df_info(df)
# Out:
# Shape: (13605401, 8)
#                        DataType  #Nulls  #Uniques
# SK_ID_PREV                int64       0    997752
# SK_ID_CURR                int64       0    339587
# NUM_INSTALMENT_VERSION  float64       0        65
# NUM_INSTALMENT_NUMBER     int64       0       277
# DAYS_INSTALMENT         float64       0      2922
# DAYS_ENTRY_PAYMENT      float64    2905      3039
# AMT_INSTALMENT          float64       0    902539
# AMT_PAYMENT             float64    2905    944235

# %%
df.sort_values(['SK_ID_CURR', 'SK_ID_PREV'])
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 1478621      1369693      100001                     1.0
# 2568722      1369693      100001                     1.0
# 2624024      1369693      100001                     2.0
# 3458712      1369693      100001                     1.0
# 1761012      1851984      100001                     1.0
# 3435373      1851984      100001                     1.0
# 3774071      1851984      100001                     1.0
# 185679       1038818      100002                     1.0
# 210205       1038818      100002                     1.0
# 442432       1038818      100002                     2.0
# 504426       1038818      100002                     1.0
# 607863       1038818      100002                     1.0
# 699804       1038818      100002                     1.0
# 740300       1038818      100002                     1.0
# 916044       1038818      100002                     1.0
# ...

# %%
df.sort_values(['SK_ID_PREV', 'SK_ID_CURR'])
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 512588       1000001      158271                     1.0
# 2159480      1000001      158271                     2.0
# 1006868      1000002      101962                     2.0
# 1214732      1000002      101962                     1.0
# 1631862      1000002      101962                     1.0
# 3411021      1000002      101962                     1.0
# 4279518      1000003      252457                     1.0
# 6145031      1000003      252457                     1.0
# 7054246      1000003      252457                     1.0
# 4242475      1000004      260094                     1.0
# 4713874      1000004      260094                     2.0
# 5197652      1000004      260094                     1.0
# 5575422      1000004      260094                     1.0
# 5737330      1000004      260094                     1.0
# 5959838      1000004      260094                     1.0
# ...

# %%
df.groupby(['SK_ID_PREV', 'SK_ID_CURR', 'NUM_INSTALMENT_NUMBER']).size().max()
# Out:
# 12
