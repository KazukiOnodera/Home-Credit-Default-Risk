# %%
import pandas as pd
import numpy as np
from glob import glob
from IPython.display import display
pd.set_option('display.max_columns', 99)
pd.set_option('display.max_rows', 99)
import EDA
import utils
sorted(glob('../data/*'))
# Out:
# ['../data/101_test',
#  '../data/101_train',
#  '../data/102_CHANNEL_TYPE_test',
#  '../data/102_CHANNEL_TYPE_train',
#  '../data/102_CODE_REJECT_REASON_test',
#  '../data/102_CODE_REJECT_REASON_train',
#  '../data/102_NAME_CASH_LOAN_PURPOSE_test',
#  '../data/102_NAME_CASH_LOAN_PURPOSE_train',
#  '../data/102_NAME_CLIENT_TYPE_test',
#  '../data/102_NAME_CLIENT_TYPE_train',
#  '../data/102_NAME_CONTRACT_STATUS_test',
#  '../data/102_NAME_CONTRACT_STATUS_train',
#  '../data/102_NAME_CONTRACT_TYPE_test',
#  '../data/102_NAME_CONTRACT_TYPE_train',
#  '../data/102_NAME_GOODS_CATEGORY_test',
#  '../data/102_NAME_GOODS_CATEGORY_train',
#  '../data/102_NAME_PAYMENT_TYPE_test',
#  '../data/102_NAME_PAYMENT_TYPE_train',
#  '../data/102_NAME_PORTFOLIO_test',
#  '../data/102_NAME_PORTFOLIO_train',
#  '../data/102_NAME_PRODUCT_TYPE_test',
#  '../data/102_NAME_PRODUCT_TYPE_train',
#  '../data/102_NAME_SELLER_INDUSTRY_test',
#  '../data/102_NAME_SELLER_INDUSTRY_train',
# ...

# %%
df = utils.read_pickles('../data/credit_card_balance').sort_values(['SK_ID_CURR', 'SK_ID_PREV', 'MONTHS_BALANCE'])
df.head()
# Out:
# 100%|██████████| 20/20 [00:06<00:00,  3.07it/s]
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 1636141     1489396      100006              -6          0.0
# 655566      1489396      100006              -5          0.0
# 1399895     1489396      100006              -4          0.0
# 1347528     1489396      100006              -3          0.0
# 520387      1489396      100006              -2          0.0
#
#          AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 1636141                   270000                       NaN
# 655566                    270000                       NaN
# 1399895                   270000                       NaN
# 1347528                   270000                       NaN
# 520387                    270000                       NaN
#
#          AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 1636141                   0.0                         NaN
# 655566                    0.0                         NaN
# ...

# %%
EDA.df_info(df)
# Out:
# Shape: (3840312, 23)
#                            DataType  #Nulls  #Uniques          Min  \
# SK_ID_PREV                    int64       0    104307  1000018.000
# SK_ID_CURR                    int64       0    103558   100006.000
# MONTHS_BALANCE                int64       0        96      -96.000
# AMT_BALANCE                 float64       0   1347904  -420250.185
# AMT_CREDIT_LIMIT_ACTUAL       int64       0       181        0.000
# AMT_DRAWINGS_ATM_CURRENT    float64  749816      2267    -6827.310
# AMT_DRAWINGS_CURRENT        float64       0    187005    -6211.620
# AMT_DRAWINGS_OTHER_CURRENT  float64  749816      1832        0.000
# AMT_DRAWINGS_POS_CURRENT    float64  749816    168748        0.000
# AMT_INST_MIN_REGULARITY     float64  305236    312266        0.000
# AMT_PAYMENT_CURRENT         float64  767988    163209        0.000
# AMT_PAYMENT_TOTAL_CURRENT   float64       0    182957        0.000
# AMT_RECEIVABLE_PRINCIPAL    float64       0   1195839  -423305.820
# ...

# %%
df.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'AMT_BALANCE',
#        'AMT_CREDIT_LIMIT_ACTUAL', 'AMT_DRAWINGS_ATM_CURRENT',
#        'AMT_DRAWINGS_CURRENT', 'AMT_DRAWINGS_OTHER_CURRENT',
#        'AMT_DRAWINGS_POS_CURRENT', 'AMT_INST_MIN_REGULARITY',
#        'AMT_PAYMENT_CURRENT', 'AMT_PAYMENT_TOTAL_CURRENT',
#        'AMT_RECEIVABLE_PRINCIPAL', 'AMT_RECIVABLE', 'AMT_TOTAL_RECEIVABLE',
#        'CNT_DRAWINGS_ATM_CURRENT', 'CNT_DRAWINGS_CURRENT',
#        'CNT_DRAWINGS_OTHER_CURRENT', 'CNT_DRAWINGS_POS_CURRENT',
#        'CNT_INSTALMENT_MATURE_CUM', 'NAME_CONTRACT_STATUS', 'SK_DPD',
#        'SK_DPD_DEF'],
#       dtype='object')

# %%
df
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 1636141     1489396      100006              -6        0.000
# 655566      1489396      100006              -5        0.000
# 1399895     1489396      100006              -4        0.000
# 1347528     1489396      100006              -3        0.000
# 520387      1489396      100006              -2        0.000
# 584804      1489396      100006              -1        0.000
# 3131464     1843384      100011             -75   189000.000
# 2447092     1843384      100011             -74   184568.850
# 2353190     1843384      100011             -73   181044.540
# 1086495     1843384      100011             -72   177544.350
# 1872143     1843384      100011             -71   173901.915
# 1189825     1843384      100011             -70   170289.720
# 3805973     1843384      100011             -69   166628.160
# 3245151     1843384      100011             -68   162659.970
# ...

# %%
ids = df.SK_ID_CURR.unique()

# %%
tmp = df[df.SK_ID_CURR==np.random.choice(ids)]
tmp
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 653545      2050990      293127             -96    47970.900
# 2441598     2050990      293127             -95    45738.495
# 3751644     2050990      293127             -94    43462.755
# 831889      2050990      293127             -93    41078.655
# 1164607     2050990      293127             -92    34354.620
# 1923186     2050990      293127             -91    31601.565
# 748215      2050990      293127             -90    25908.480
# 2080973     2050990      293127             -89    22808.475
# 2260058     2050990      293127             -88    38684.970
# 3405389     2050990      293127             -87    36112.995
# 2477094     2050990      293127             -86    62479.980
# 2804068     2050990      293127             -85    64902.375
# 2797329     2050990      293127             -84    67991.715
# 3002219     2050990      293127             -83    66343.950
# ...

# %%
tmp = df[df.SK_ID_CURR==100006]
tmp
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 1636141     1489396      100006              -6          0.0
# 655566      1489396      100006              -5          0.0
# 1399895     1489396      100006              -4          0.0
# 1347528     1489396      100006              -3          0.0
# 520387      1489396      100006              -2          0.0
# 584804      1489396      100006              -1          0.0
#
#          AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 1636141                   270000                       NaN
# 655566                    270000                       NaN
# 1399895                   270000                       NaN
# 1347528                   270000                       NaN
# 520387                    270000                       NaN
# 584804                    270000                       NaN
#
#          AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# ...

# %%
449.685 + 8974.215 + 5164.650
# Out:
# 14588.55
