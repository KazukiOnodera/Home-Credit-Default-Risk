# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
imp = pd.read_csv('LOG/imp_909_cv.py.csv')

# %%
def pltImp(imp, x='gain', y='col', n=30, title='Importance'):
    
    g = sns.barplot(x=x, y=y, data=imp.head(n),
            label=x)
    g.figsize(15,15)
    plt.subplots_adjust(left=.4, right=.9)
    plt.title(title+' TOP{0}'.format(n), fontsize=20, alpha=0.5)
    #plt.figure(figsize = ( 20 , 10 )) 
    plt.show()

# %%
pltImp(imp, y='feature', n=50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-eb82106147c3> in <module>()
# ----> 1 pltImp(imp, y='feature', n=50)
#
# <ipython-input-11-530314132b6d> in pltImp(imp, x, y, n, title)
#       3     g = sns.barplot(x=x, y=y, data=imp.head(n),
#       4             label=x)
# ----> 5     g.figsize(15,15)
#       6     plt.subplots_adjust(left=.4, right=.9)
#       7     plt.title(title+' TOP{0}'.format(n), fontsize=20, alpha=0.5)
#
# AttributeError: 'AxesSubplot' object has no attribute 'figsize'
