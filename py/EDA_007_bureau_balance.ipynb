# %%
import pandas as pd
import numpy as np
from glob import glob
from IPython.display import display
pd.set_option('display.max_columns', 99)
pd.set_option('display.max_rows', 99)
import EDA
import utils
sorted(glob('../data/*'))
# Out:
# ['../data/101_test',
#  '../data/101_train',
#  '../data/102_CHANNEL_TYPE_test',
#  '../data/102_CHANNEL_TYPE_train',
#  '../data/102_CODE_REJECT_REASON_test',
#  '../data/102_CODE_REJECT_REASON_train',
#  '../data/102_NAME_CASH_LOAN_PURPOSE_test',
#  '../data/102_NAME_CASH_LOAN_PURPOSE_train',
#  '../data/102_NAME_CLIENT_TYPE_test',
#  '../data/102_NAME_CLIENT_TYPE_train',
#  '../data/102_NAME_CONTRACT_STATUS_test',
#  '../data/102_NAME_CONTRACT_STATUS_train',
#  '../data/102_NAME_CONTRACT_TYPE_test',
#  '../data/102_NAME_CONTRACT_TYPE_train',
#  '../data/102_NAME_GOODS_CATEGORY_test',
#  '../data/102_NAME_GOODS_CATEGORY_train',
#  '../data/102_NAME_PAYMENT_TYPE_test',
#  '../data/102_NAME_PAYMENT_TYPE_train',
#  '../data/102_NAME_PORTFOLIO_test',
#  '../data/102_NAME_PORTFOLIO_train',
#  '../data/102_NAME_PRODUCT_TYPE_test',
#  '../data/102_NAME_PRODUCT_TYPE_train',
#  '../data/102_NAME_SELLER_INDUSTRY_test',
#  '../data/102_NAME_SELLER_INDUSTRY_train',
# ...

# %%
df = utils.read_pickles('../data/bureau_balance')
df.head()
# Out:
# 100%|██████████| 20/20 [00:06<00:00,  2.95it/s]
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C
# 3       5715448              -3      C
# 4       5715448              -4      C

# %%
EDA.df_info(df)
# Out:
# Shape: (27299925, 3)
#                DataType  #Nulls  #Uniques        Min          Mean        Max  \
# SK_ID_BUREAU      int64       0    817395  5001709.0  6.036297e+06  6842888.0
# MONTHS_BALANCE    int64       0        97      -96.0 -3.074169e+01        0.0
# STATUS           object       0         8        NaN           NaN        NaN
#
#                           Std  \
# SK_ID_BUREAU    492348.856904
# MONTHS_BALANCE      23.864509
# STATUS                    NaN
#
#                                                         top10 val  \
# SK_ID_BUREAU    [6104966, 5760763, 5568354, 6365230, 6635521, ...
# MONTHS_BALANCE            [-1, -2, -3, 0, -4, -5, -6, -7, -8, -9]
# STATUS                   ['C', '0', 'X', '1', '5', '2', '3', '4']
#
#                                                         top10 cnt
# SK_ID_BUREAU             [97, 97, 97, 97, 97, 97, 97, 97, 97, 97]
# MONTHS_BALANCE  [622601, 619243, 615080, 610965, 609138, 60266...
# ...

# %%
df.sort_values(['SK_ID_BUREAU', 'MONTHS_BALANCE'], inplace=True)
df
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 26079849       5001709             -96      X
# 26079848       5001709             -95      X
# 26079847       5001709             -94      X
# 26079846       5001709             -93      X
# 26079845       5001709             -92      X
# 26079844       5001709             -91      X
# 26079843       5001709             -90      X
# 26079842       5001709             -89      X
# 26079841       5001709             -88      X
# 26079840       5001709             -87      X
# 26079839       5001709             -86      X
# 26079838       5001709             -85      C
# 26079837       5001709             -84      C
# 26079836       5001709             -83      C
# 26079835       5001709             -82      C
# 26079834       5001709             -81      C
# 26079833       5001709             -80      C
# 26079832       5001709             -79      C
# 26079831       5001709             -78      C
# ...

# %%
ids = df.SK_ID_BUREAU.unique()

# %%
df[df.SK_ID_BUREAU==np.random.choice(ids)]
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 14926239       6356356             -32      0
# 14926238       6356356             -31      0
# 14926237       6356356             -30      0
# 14926236       6356356             -29      0
# 14926235       6356356             -28      0
# 14926234       6356356             -27      0
# 14926233       6356356             -26      0
# 14926232       6356356             -25      0
# 14926231       6356356             -24      0
# 14926230       6356356             -23      0
# 14926229       6356356             -22      0
# 14926228       6356356             -21      0
# 14926227       6356356             -20      0
# 14926226       6356356             -19      0
# 14926225       6356356             -18      0
# 14926224       6356356             -17      0
# 14926223       6356356             -16      1
# 14926222       6356356             -15      0
# 14926221       6356356             -14      0
# ...

# %%
df[df.SK_ID_BUREAU==5896635]
# Out:
#          SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 4040747       5896635               0      0
# 4040748       5896635              -1      X

# %%
df[df.SK_ID_BUREAU==5896636]
# Out:
#          SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 4040749       5896636               0      0
# 4040750       5896636              -1      0
# 4040751       5896636              -2      0
# 4040752       5896636              -3      0
# 4040753       5896636              -4      0
# 4040754       5896636              -5      0
# 4040755       5896636              -6      0
# 4040756       5896636              -7      0
# 4040757       5896636              -8      0
# 4040758       5896636              -9      0
# 4040759       5896636             -10      0

# %%
df[df.SK_ID_BUREAU==6113835]
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 22638292       6113835             -34      X
# 22638291       6113835             -33      X
# 22638290       6113835             -32      0
# 22638289       6113835             -31      0
# 22638288       6113835             -30      0
# 22638287       6113835             -29      0
# 22638286       6113835             -28      1
# 22638285       6113835             -27      1
# 22638284       6113835             -26      X
# 22638283       6113835             -25      1
# 22638282       6113835             -24      1
# 22638281       6113835             -23      0
# 22638280       6113835             -22      1
# 22638279       6113835             -21      1
# 22638278       6113835             -20      C
# 22638277       6113835             -19      C

# %%
df[df.SK_ID_BUREAU==6158903]
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 19443487       6158903             -34      X
# 19443486       6158903             -33      X
# 19443485       6158903             -32      0
# 19443484       6158903             -31      0
# 19443483       6158903             -30      0
# 19443482       6158903             -29      0
# 19443481       6158903             -28      1
# 19443480       6158903             -27      1
# 19443479       6158903             -26      X
# 19443478       6158903             -25      1
# 19443477       6158903             -24      1
# 19443476       6158903             -23      0
# 19443475       6158903             -22      1
# 19443474       6158903             -21      1
# 19443473       6158903             -20      C
# 19443472       6158903             -19      C
