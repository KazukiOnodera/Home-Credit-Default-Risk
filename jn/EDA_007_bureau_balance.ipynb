# %%
import pandas as pd
import numpy as np
from glob import glob
from IPython.display import display
pd.set_option('display.max_columns', 99)
pd.set_option('display.max_rows', 99)
from matplotlib import pyplot as plt
import EDA
import utils
#sorted(glob('../data/*'))

# %%
df = utils.read_pickles('../data/bureau_balance').sort_values(['SK_ID_BUREAU', 'MONTHS_BALANCE'], ascending=[True, False])
df.head()
# Out:
# 100%|██████████| 20/20 [00:06<00:00,  3.00it/s]
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 26079753       5001709               0      C
# 26079754       5001709              -1      C
# 26079755       5001709              -2      C
# 26079756       5001709              -3      C
# 26079757       5001709              -4      C

# %%
EDA.df_info(df)
# Out:
# Shape: (27299925, 3)
#                DataType  #Nulls  #Uniques        Min          Mean        Max  \
# SK_ID_BUREAU      int64       0    817395  5001709.0  6.036297e+06  6842888.0
# MONTHS_BALANCE    int64       0        97      -96.0 -3.074169e+01        0.0
# STATUS           object       0         8        NaN           NaN        NaN
#
#                           Std  \
# SK_ID_BUREAU    492348.856904
# MONTHS_BALANCE      23.864509
# STATUS                    NaN
#
#                                                         top10 val  \
# SK_ID_BUREAU    [6104966, 5760763, 5568354, 6365230, 6635521, ...
# MONTHS_BALANCE            [-1, -2, -3, 0, -4, -5, -6, -7, -8, -9]
# STATUS                   ['C', '0', 'X', '1', '5', '2', '3', '4']
#
#                                                         top10 cnt  \
# SK_ID_BUREAU             [97, 97, 97, 97, 97, 97, 97, 97, 97, 97]
# MONTHS_BALANCE  [622601, 619243, 615080, 610965, 609138, 60266...
# ...

# %%
df.MONTHS_BALANCE.hist(bins=30); plt.show()

# %%
ids = df.SK_ID_BUREAU.unique()

# %%
tmp = df[df.SK_ID_BUREAU.isin(np.random.choice(ids, size=9))]
tmp
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 1404803        5229582               0      X
# 1404804        5229582              -1      X
# 1404805        5229582              -2      X
# 1404806        5229582              -3      X
# 1404807        5229582              -4      0
# 1404808        5229582              -5      0
# 1404809        5229582              -6      X
# 1404810        5229582              -7      0
# 1404811        5229582              -8      0
# 1404812        5229582              -9      X
# 1404813        5229582             -10      0
# 1404814        5229582             -11      X
# 1404815        5229582             -12      0
# 1404816        5229582             -13      0
# 1404817        5229582             -14      X
# 1404818        5229582             -15      0
# 1404819        5229582             -16      X
# 1404820        5229582             -17      X
# 1404821        5229582             -18      0
# ...

# %%
tmp.to_csv('sample_bb.csv', index=False)
