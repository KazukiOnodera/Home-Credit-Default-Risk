# %%
import gc, os
from tqdm import tqdm
import pandas as pd
import numpy as np
import sys
sys.path.append(f'/home/{os.environ.get("USER")}/PythonLibrary')
import lgbextension as ex
import lightgbm as lgb
from matplotlib import pyplot as plt
from multiprocessing import cpu_count, Pool
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GroupKFold
from glob import glob

# %%
NFOLD = 5

# %%
train = pd.read_csv('../input/application_train.csv.zip')

# %%
prev = pd.read_csv('../input/previous_application.csv.zip')

# %%
X_train, X_test = prev.align(train, join='inner', axis=1)

# %%
X_train.drop('SK_ID_CURR', axis=1, inplace=True)
X_train.head()
# Out:
#    NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_CREDIT  AMT_GOODS_PRICE  \
# 0                   1     1730.430     17145.0          17145.0
# 1                   0    25188.615    679671.0         607500.0
# 2                   0    15060.735    136444.5         112500.0
# 3                   0    47041.335    470790.0         450000.0
# 4                   0    31924.395    404055.0         337500.0
#
#    WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  NAME_TYPE_SUITE
# 0                           2                       15                7
# 1                           4                       11                6
# 2                           5                       11                5
# 3                           1                        7                7
# 4                           4                        9                7

# %%
prev[X_test.columns.tolist()+['NAME_SELLER_INDUSTRY']].head()
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_CREDIT  AMT_GOODS_PRICE  \
# 0      271877     Consumer loans     1730.430     17145.0          17145.0
# 1      108129         Cash loans    25188.615    679671.0         607500.0
# 2      122040         Cash loans    15060.735    136444.5         112500.0
# 3      176158         Cash loans    47041.335    470790.0         450000.0
# 4      202054         Cash loans    31924.395    404055.0         337500.0
#
#   WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  NAME_TYPE_SUITE  \
# 0                   SATURDAY                       15              NaN
# 1                   THURSDAY                       11    Unaccompanied
# 2                    TUESDAY                       11  Spouse, partner
# 3                     MONDAY                        7              NaN
# 4                   THURSDAY                        9              NaN
#
#   NAME_SELLER_INDUSTRY
# 0         Connectivity
# 1                  XNA
# 2                  XNA
# 3                  XNA
# 4                  XNA

# %%
col_cat = X_train.head().select_dtypes('O').columns.tolist()

# %%
col_cat
# Out:
# ['NAME_CONTRACT_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'NAME_TYPE_SUITE']

# %%
le = LabelEncoder()
for c in col_cat:
    X_train[c].fillna('na dayo', inplace=True)
    X_test[c].fillna('na dayo', inplace=True)
    le.fit( X_train[c].append(X_test[c]) )
    X_train[c] = le.transform(X_train[c])
    X_test[c]  = le.transform(X_test[c])

# %%
y_names = prev.columns.difference(X_train.columns).tolist()
y_names
# Out:
# ['AMT_APPLICATION',
#  'AMT_DOWN_PAYMENT',
#  'CHANNEL_TYPE',
#  'CNT_PAYMENT',
#  'CODE_REJECT_REASON',
#  'DAYS_DECISION',
#  'DAYS_FIRST_DRAWING',
#  'DAYS_FIRST_DUE',
#  'DAYS_LAST_DUE',
#  'DAYS_LAST_DUE_1ST_VERSION',
#  'DAYS_TERMINATION',
#  'FLAG_LAST_APPL_PER_CONTRACT',
#  'NAME_CASH_LOAN_PURPOSE',
#  'NAME_CLIENT_TYPE',
#  'NAME_CONTRACT_STATUS',
#  'NAME_GOODS_CATEGORY',
#  'NAME_PAYMENT_TYPE',
#  'NAME_PORTFOLIO',
#  'NAME_PRODUCT_TYPE',
#  'NAME_SELLER_INDUSTRY',
#  'NAME_YIELD_GROUP',
#  'NFLAG_INSURED_ON_APPROVAL',
#  'NFLAG_LAST_APPL_IN_DAY',
#  'PRODUCT_COMBINATION',
#  'RATE_DOWN_PAYMENT',
#  'RATE_INTEREST_PRIMARY',
#  'RATE_INTEREST_PRIVILEGED',
#  'SELLERPLACE_AREA',
#  'SK_ID_PREV']

# %%
prev[y_names].dtypes
# Out:
# AMT_APPLICATION                float64
# AMT_DOWN_PAYMENT               float64
# CHANNEL_TYPE                    object
# CNT_PAYMENT                    float64
# CODE_REJECT_REASON              object
# DAYS_DECISION                    int64
# DAYS_FIRST_DRAWING             float64
# DAYS_FIRST_DUE                 float64
# DAYS_LAST_DUE                  float64
# DAYS_LAST_DUE_1ST_VERSION      float64
# DAYS_TERMINATION               float64
# FLAG_LAST_APPL_PER_CONTRACT     object
# NAME_CASH_LOAN_PURPOSE          object
# NAME_CLIENT_TYPE                object
# NAME_CONTRACT_STATUS            object
# NAME_GOODS_CATEGORY             object
# NAME_PAYMENT_TYPE               object
# NAME_PORTFOLIO                  object
# NAME_PRODUCT_TYPE               object
# NAME_SELLER_INDUSTRY            object
# NAME_YIELD_GROUP                object
# NFLAG_INSURED_ON_APPROVAL      float64
# NFLAG_LAST_APPL_IN_DAY           int64
# PRODUCT_COMBINATION             object
# RATE_DOWN_PAYMENT              float64
# RATE_INTEREST_PRIMARY          float64
# RATE_INTEREST_PRIVILEGED       float64
# SELLERPLACE_AREA                 int64
# SK_ID_PREV                       int64
# dtype: object

# %%
prev[y_names].isnull().sum()
# Out:
# AMT_APPLICATION                      0
# AMT_DOWN_PAYMENT                895844
# CHANNEL_TYPE                         0
# CNT_PAYMENT                     372230
# CODE_REJECT_REASON                   0
# DAYS_DECISION                        0
# DAYS_FIRST_DRAWING              673065
# DAYS_FIRST_DUE                  673065
# DAYS_LAST_DUE                   673065
# DAYS_LAST_DUE_1ST_VERSION       673065
# DAYS_TERMINATION                673065
# FLAG_LAST_APPL_PER_CONTRACT          0
# NAME_CASH_LOAN_PURPOSE               0
# NAME_CLIENT_TYPE                     0
# NAME_CONTRACT_STATUS                 0
# NAME_GOODS_CATEGORY                  0
# NAME_PAYMENT_TYPE                    0
# NAME_PORTFOLIO                       0
# NAME_PRODUCT_TYPE                    0
# NAME_SELLER_INDUSTRY                 0
# NAME_YIELD_GROUP                     0
# NFLAG_INSURED_ON_APPROVAL       673065
# NFLAG_LAST_APPL_IN_DAY               0
# PRODUCT_COMBINATION                346
# RATE_DOWN_PAYMENT               895844
# RATE_INTEREST_PRIMARY          1664263
# RATE_INTEREST_PRIVILEGED       1664263
# SELLERPLACE_AREA                     0
# SK_ID_PREV                           0
# dtype: int64

# %%
prev[y_names].head()
# Out:
#    AMT_APPLICATION  AMT_DOWN_PAYMENT             CHANNEL_TYPE  CNT_PAYMENT  \
# 0          17145.0               0.0             Country-wide         12.0
# 1         607500.0               NaN           Contact center         36.0
# 2         112500.0               NaN  Credit and cash offices         12.0
# 3         450000.0               NaN  Credit and cash offices         12.0
# 4         337500.0               NaN  Credit and cash offices         24.0
#
#   CODE_REJECT_REASON  DAYS_DECISION  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  \
# 0                XAP            -73            365243.0           -42.0
# 1                XAP           -164            365243.0          -134.0
# 2                XAP           -301            365243.0          -271.0
# 3                XAP           -512            365243.0          -482.0
# 4                 HC           -781                 NaN             NaN
#
#    DAYS_LAST_DUE  DAYS_LAST_DUE_1ST_VERSION    ...      NAME_SELLER_INDUSTRY  \
# 0          -42.0                      300.0    ...              Connectivity
# 1       365243.0                      916.0    ...                       XNA
# 2       365243.0                       59.0    ...                       XNA
# 3         -182.0                     -152.0    ...                       XNA
# 4            NaN                        NaN    ...                       XNA
#
#   NAME_YIELD_GROUP NFLAG_INSURED_ON_APPROVAL NFLAG_LAST_APPL_IN_DAY  \
# 0           middle                       0.0                      1
# 1       low_action                       1.0                      1
# 2             high                       1.0                      1
# 3           middle                       1.0                      1
# 4             high                       NaN                      1
#
#         PRODUCT_COMBINATION RATE_DOWN_PAYMENT RATE_INTEREST_PRIMARY  \
# 0  POS mobile with interest               0.0              0.182832
# 1          Cash X-Sell: low               NaN                   NaN
# 2         Cash X-Sell: high               NaN                   NaN
# 3       Cash X-Sell: middle               NaN                   NaN
# 4         Cash Street: high               NaN                   NaN
#
#   RATE_INTEREST_PRIVILEGED SELLERPLACE_AREA SK_ID_PREV
# 0                 0.867336               35    2030495
# 1                      NaN               -1    2802425
# 2                      NaN               -1    2523466
# 3                      NaN               -1    2819243
# 4                      NaN               -1    1784265
#
# [5 rows x 29 columns]

# %%
SEED = 71

param_bin = {
         'objective': 'binary',
         'metric': 'auc',
         'learning_rate': 0.01,
         
         'max_depth': 6,
         'num_leaves': 63,
         'max_bin': 255,
         
         'min_child_weight': 10,
         'min_data_in_leaf': 150,
         'reg_lambda': 0.5,  # L2 regularization term on weights.
         'reg_alpha': 0.5,  # L1 regularization term on weights.
         
         'colsample_bytree': 0.9,
         'subsample': 0.9,
#         'nthread': 32,
         'nthread': cpu_count(),
         'bagging_freq': 1,
         'verbose':-1,
         'seed': SEED
         }


param_reg = {
         'objective': 'regression',
         'metric': 'rmse',
         'learning_rate': 0.01,
         
         'max_depth': 6,
         'num_leaves': 63,
         'max_bin': 255,
         
         'min_child_weight': 10,
         'min_data_in_leaf': 150,
         'reg_lambda': 0.5,  # L2 regularization term on weights.
         'reg_alpha': 0.5,  # L1 regularization term on weights.
         
         'colsample_bytree': 0.9,
         'subsample': 0.9,
#         'nthread': 32,
         'nthread': cpu_count(),
         'bagging_freq': 1,
         'verbose':-1,
         'seed': SEED
         }

# %%
group_kfold = GroupKFold(n_splits=NFOLD)

sub_train = prev[['SK_ID_CURR']]
sub_train['g'] = sub_train.SK_ID_CURR % NFOLD
# Out:
# /home/Kazuki/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
y_name = y_names[0]

# %%
y = prev[y_name]

# %%
dtrain = lgb.Dataset(X_train, y.map(np.log1p), categorical_feature=col_cat )
gc.collect()

ret, models = lgb.cv(param_reg, dtrain, 99999, stratified=False,
                     folds=group_kfold.split(X_train, y, 
                                                              sub_train['g']), 
                     early_stopping_rounds=100, verbose_eval=50,
                     seed=111)
# Out:
# /home/Kazuki/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1040: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/Kazuki/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:685: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [50]	cv_agg's rmse: 3.07185 + 0.0027036
# [100]	cv_agg's rmse: 1.86975 + 0.00164737
# [150]	cv_agg's rmse: 1.1401 + 0.00104986
# [200]	cv_agg's rmse: 0.694443 + 0.000834006
# [250]	cv_agg's rmse: 0.424417 + 0.00116463
# [300]	cv_agg's rmse: 0.261803 + 0.00196494
# [350]	cv_agg's rmse: 0.165172 + 0.00318776
# [400]	cv_agg's rmse: 0.107636 + 0.00497619
# [450]	cv_agg's rmse: 0.0756826 + 0.00716195
# [500]	cv_agg's rmse: 0.0583175 + 0.00938678
# [550]	cv_agg's rmse: 0.0497306 + 0.0111414
# [600]	cv_agg's rmse: 0.0457236 + 0.0122381
# [650]	cv_agg's rmse: 0.0437599 + 0.012881
# [700]	cv_agg's rmse: 0.0427608 + 0.0132542
# [750]	cv_agg's rmse: 0.0422582 + 0.0134538
# [800]	cv_agg's rmse: 0.0420215 + 0.0135494
# [850]	cv_agg's rmse: 0.0418701 + 0.0136045
# [900]	cv_agg's rmse: 0.0417752 + 0.0136433
# [950]	cv_agg's rmse: 0.0416709 + 0.0136799
# [1000]	cv_agg's rmse: 0.0415476 + 0.0137071
# [1050]	cv_agg's rmse: 0.0414483 + 0.0137284
# [1100]	cv_agg's rmse: 0.0413735 + 0.0137448
# [1150]	cv_agg's rmse: 0.0413096 + 0.0137523
# [1200]	cv_agg's rmse: 0.0412551 + 0.013768
# [1250]	cv_agg's rmse: 0.0412072 + 0.0137805
# [1300]	cv_agg's rmse: 0.0411668 + 0.0137879
# [1350]	cv_agg's rmse: 0.0411228 + 0.0138011
# [1400]	cv_agg's rmse: 0.041079 + 0.0138104
# [1450]	cv_agg's rmse: 0.0410498 + 0.013812
# [1500]	cv_agg's rmse: 0.0410189 + 0.0138191
# [1550]	cv_agg's rmse: 0.0409943 + 0.0138167
# [1600]	cv_agg's rmse: 0.040966 + 0.0138219
# [1650]	cv_agg's rmse: 0.0409442 + 0.0138251
# [1700]	cv_agg's rmse: 0.040924 + 0.0138256
# [1750]	cv_agg's rmse: 0.0409079 + 0.0138318
# [1800]	cv_agg's rmse: 0.0408952 + 0.0138332
# [1850]	cv_agg's rmse: 0.0408816 + 0.0138354
# [1900]	cv_agg's rmse: 0.0408602 + 0.0138358
# [1950]	cv_agg's rmse: 0.0408479 + 0.0138394
# [2000]	cv_agg's rmse: 0.0408322 + 0.0138415
# [2050]	cv_agg's rmse: 0.0408232 + 0.0138365
# [2100]	cv_agg's rmse: 0.0408124 + 0.0138413
# [2150]	cv_agg's rmse: 0.0408006 + 0.0138429
# [2200]	cv_agg's rmse: 0.0407939 + 0.0138405
# [2250]	cv_agg's rmse: 0.040785 + 0.0138408
# [2300]	cv_agg's rmse: 0.0407758 + 0.0138395
# [2350]	cv_agg's rmse: 0.0407659 + 0.0138421
# [2400]	cv_agg's rmse: 0.0407591 + 0.0138403
# [2450]	cv_agg's rmse: 0.0407517 + 0.0138396
# [2500]	cv_agg's rmse: 0.040741 + 0.013838
# [2550]	cv_agg's rmse: 0.0407321 + 0.0138343
# [2600]	cv_agg's rmse: 0.0407262 + 0.0138319
# [2650]	cv_agg's rmse: 0.0407193 + 0.0138313
# [2700]	cv_agg's rmse: 0.0407097 + 0.0138301
# [2750]	cv_agg's rmse: 0.0407067 + 0.013829
# [2800]	cv_agg's rmse: 0.0406998 + 0.0138261
# [2850]	cv_agg's rmse: 0.0406908 + 0.0138264
# [2900]	cv_agg's rmse: 0.0406847 + 0.0138293
# [2950]	cv_agg's rmse: 0.0406785 + 0.0138261
# [3000]	cv_agg's rmse: 0.0406715 + 0.013825
# [3050]	cv_agg's rmse: 0.0406681 + 0.0138218
# [3100]	cv_agg's rmse: 0.0406608 + 0.0138232
# [3150]	cv_agg's rmse: 0.0406516 + 0.0138295
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-b5980842ee72> in <module>()
#       4 ret, models = lgb.cv(param_reg, dtrain, 99999, nfold=7, stratified=False,
#       5                      early_stopping_rounds=100, verbose_eval=50,
# ----> 6                      seed=111)
#
# ~/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py in cv(params, train_set, num_boost_round, folds, nfold, stratified, shuffle, metrics, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, fpreproc, verbose_eval, show_stdv, seed, callbacks)
#     449                                     end_iteration=num_boost_round,
#     450                                     evaluation_result_list=None))
# --> 451         cvfolds.update(fobj=fobj)
#     452         res = _agg_cv_result(cvfolds.eval_valid(feval))
#     453         for _, key, mean, _, std in res:
#
# ~/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py in handlerFunction(*args, **kwargs)
#     247             ret = []
#     248             for booster in self.boosters:
# --> 249                 ret.append(getattr(booster, name)(*args, **kwargs))
#     250             return ret
#     251         return handlerFunction
#
# ~/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1526             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1527                 self.handle,
# -> 1528                 ctypes.byref(is_finished)))
#    1529             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1530             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
X_train.head()
# Out:
#    SK_ID_CURR  NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_CREDIT  AMT_GOODS_PRICE  \
# 0      271877                   1     1730.430     17145.0          17145.0
# 1      108129                   0    25188.615    679671.0         607500.0
# 2      122040                   0    15060.735    136444.5         112500.0
# 3      176158                   0    47041.335    470790.0         450000.0
# 4      202054                   0    31924.395    404055.0         337500.0
#
#    WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  NAME_TYPE_SUITE
# 0                           2                       15                7
# 1                           4                       11                6
# 2                           5                       11                5
# 3                           1                        7                7
# 4                           4                        9                7

# %%
y
# Out:
#          AMT_APPLICATION  AMT_DOWN_PAYMENT             CHANNEL_TYPE  \
# 0                17145.0               0.0             Country-wide
# 1               607500.0               NaN           Contact center
# 2               112500.0               NaN  Credit and cash offices
# 3               450000.0               NaN  Credit and cash offices
# 4               337500.0               NaN  Credit and cash offices
# 5               315000.0               NaN  Credit and cash offices
# 6                    0.0               NaN  Credit and cash offices
# 7                    0.0               NaN  Credit and cash offices
# 8                    0.0               NaN  Credit and cash offices
# 9                    0.0               NaN  Credit and cash offices
# 10              270000.0               NaN  Credit and cash offices
# 11              211500.0               NaN  Credit and cash offices
# 12              148500.0               NaN  Credit and cash offices
# 13               53779.5               0.0             Country-wide
# 14               26550.0               0.0                    Stone
# 15              126490.5           12649.5         Regional / Local
# 16               26955.0            1350.0                    Stone
# 17              180000.0               NaN          AP+ (Cash loan)
# 18              180000.0               NaN          AP+ (Cash loan)
# 19               45000.0               NaN          AP+ (Cash loan)
# 20              450000.0               NaN  Credit and cash offices
# 21              405000.0               NaN  Credit and cash offices
# 22                   0.0               NaN  Credit and cash offices
# 23             1129500.0               NaN  Credit and cash offices
# 24                   0.0               NaN  Credit and cash offices
# 25              229500.0               NaN  Credit and cash offices
# 26              369000.0               NaN             Country-wide
# 27              247500.0               0.0             Country-wide
# 28               74610.0            9000.0                    Stone
# 29                   0.0               NaN  Credit and cash offices
# ...                  ...               ...                      ...
# 1670184        1575000.0               NaN           Contact center
# 1670185         450000.0               NaN           Contact center
# 1670186              0.0               NaN           Contact center
# 1670187              0.0               NaN           Contact center
# 1670188         900000.0               NaN           Contact center
# 1670189         796500.0               NaN           Contact center
# 1670190              0.0               NaN           Contact center
# 1670191          45000.0               NaN                    Stone
# 1670192              0.0               NaN          AP+ (Cash loan)
# 1670193              0.0               NaN          AP+ (Cash loan)
# 1670194          90000.0               NaN          AP+ (Cash loan)
# 1670195         248535.0           24853.5             Country-wide
# 1670196          57910.5               0.0             Country-wide
# 1670197         153220.5               0.0         Regional / Local
# 1670198          22869.0            2290.5             Country-wide
# 1670199          37926.0               0.0             Country-wide
# 1670200          99000.0               0.0             Country-wide
# 1670201          45450.0            2295.0                    Stone
# 1670202          22207.5               0.0                    Stone
# 1670203          14791.5               0.0                    Stone
# 1670204         450000.0               NaN  Credit and cash offices
# 1670205         135000.0               NaN  Credit and cash offices
# 1670206         180000.0               0.0  Credit and cash offices
# 1670207         112500.0               0.0  Credit and cash offices
# 1670208         315000.0               NaN  Credit and cash offices
# 1670209         267295.5               0.0                    Stone
# 1670210          87750.0           29250.0                    Stone
# 1670211         105237.0           10525.5             Country-wide
# 1670212         180000.0               NaN          AP+ (Cash loan)
# 1670213         360000.0               NaN          AP+ (Cash loan)
#
#          CNT_PAYMENT CODE_REJECT_REASON  DAYS_DECISION  DAYS_FIRST_DRAWING  \
# 0               12.0                XAP            -73            365243.0
# 1               36.0                XAP           -164            365243.0
# 2               12.0                XAP           -301            365243.0
# 3               12.0                XAP           -512            365243.0
# 4               24.0                 HC           -781                 NaN
# 5               18.0                XAP           -684            365243.0
# 6                NaN                XAP            -14                 NaN
# 7                NaN                XAP            -21                 NaN
# 8                NaN                XAP           -386                 NaN
# 9                NaN                XAP            -57                 NaN
# 10              54.0                XAP           -735            365243.0
# 11              30.0                XAP           -815            365243.0
# 12              24.0                XAP           -860            365243.0
# 13               8.0                XAP           -408            365243.0
# 14               3.0                XAP           -726            365243.0
# 15               6.0                XAP           -699            365243.0
# 16               8.0                XAP          -1473            365243.0
# 17               0.0                XAP           -336              -277.0
# 18              24.0                XAP           -700                 NaN
# 19              18.0                 HC           -584                 NaN
# 20              24.0                 HC           -401                 NaN
# 21              30.0                XAP           -686            365243.0
# 22               NaN                 HC           -239                 NaN
# 23              54.0                 HC           -594                 NaN
# 24               NaN                XAP           -202                 NaN
# 25              12.0                XAP           -370            365243.0
# 26              48.0                XAP          -1487            365243.0
# 27              18.0                XAP          -1883            365243.0
# 28              12.0                XAP          -2702            365243.0
# 29               NaN                 HC           -430                 NaN
# ...              ...                ...            ...                 ...
# 1670184         60.0                 HC             -2                 NaN
# 1670185         12.0              LIMIT           -622                 NaN
# 1670186          NaN                XAP            -21                 NaN
# 1670187          NaN                XAP           -134                 NaN
# 1670188         60.0                XAP            -68                 NaN
# 1670189         60.0                XAP            -72                 NaN
# 1670190          NaN                XAP           -243                 NaN
# 1670191          0.0                 HC           -499                 NaN
# 1670192          0.0                XAP           -540              -474.0
# 1670193          NaN                 HC           -365                 NaN
# 1670194         12.0                XAP           -457            365243.0
# 1670195         10.0                XAP          -1389            365243.0
# 1670196          NaN             CLIENT           -289                 NaN
# 1670197         12.0              LIMIT           -636                 NaN
# 1670198         12.0                XAP           -715            365243.0
# 1670199          6.0                XAP             -6            365243.0
# 1670200         24.0                XAP          -2439            365243.0
# 1670201         12.0                XAP          -1728            365243.0
# 1670202          6.0                XAP           -979            365243.0
# 1670203          NaN                XNA          -1848                 NaN
# 1670204         24.0                 HC           -848                 NaN
# 1670205         24.0              LIMIT          -1407                 NaN
# 1670206         24.0                XAP          -1833            365243.0
# 1670207         12.0                SCO          -2514                 NaN
# 1670208         36.0                XAP          -1279            365243.0
# 1670209         30.0                XAP           -544            365243.0
# 1670210         12.0                XAP          -1694            365243.0
# 1670211         10.0                XAP          -1488            365243.0
# 1670212         12.0                XAP          -1185            365243.0
# 1670213         48.0                XAP          -1193            365243.0
#
#          DAYS_FIRST_DUE  DAYS_LAST_DUE  DAYS_LAST_DUE_1ST_VERSION    ...      \
# 0                 -42.0          -42.0                      300.0    ...
# 1                -134.0       365243.0                      916.0    ...
# 2                -271.0       365243.0                       59.0    ...
# 3                -482.0         -182.0                     -152.0    ...
# 4                   NaN            NaN                        NaN    ...
# 5                -654.0         -144.0                     -144.0    ...
# 6                   NaN            NaN                        NaN    ...
# 7                   NaN            NaN                        NaN    ...
# 8                   NaN            NaN                        NaN    ...
# 9                   NaN            NaN                        NaN    ...
# 10               -705.0         -345.0                      885.0    ...
# 11               -785.0         -725.0                       85.0    ...
# 12               -830.0         -200.0                     -140.0    ...
# 13               -378.0         -168.0                     -168.0    ...
# 14               -693.0         -633.0                     -633.0    ...
# 15               -668.0         -518.0                     -518.0    ...
# 16              -1440.0        -1230.0                    -1230.0    ...
# 17               -257.0       365243.0                   365243.0    ...
# 18                  NaN            NaN                        NaN    ...
# 19                  NaN            NaN                        NaN    ...
# 20                  NaN            NaN                        NaN    ...
# 21               -656.0       365243.0                      214.0    ...
# 22                  NaN            NaN                        NaN    ...
# 23                  NaN            NaN                        NaN    ...
# 24                  NaN            NaN                        NaN    ...
# 25               -340.0          -10.0                      -10.0    ...
# 26              -1457.0          -47.0                      -47.0    ...
# 27              -1853.0        -1343.0                    -1343.0    ...
# 28              -2671.0        -2341.0                    -2341.0    ...
# 29                  NaN            NaN                        NaN    ...
# ...                 ...            ...                        ...    ...
# 1670184             NaN            NaN                        NaN    ...
# 1670185             NaN            NaN                        NaN    ...
# 1670186             NaN            NaN                        NaN    ...
# 1670187             NaN            NaN                        NaN    ...
# 1670188             NaN            NaN                        NaN    ...
# 1670189             NaN            NaN                        NaN    ...
# 1670190             NaN            NaN                        NaN    ...
# 1670191             NaN            NaN                        NaN    ...
# 1670192          -438.0       365243.0                   365243.0    ...
# 1670193             NaN            NaN                        NaN    ...
# 1670194          -427.0          -97.0                      -97.0    ...
# 1670195         -1354.0        -1084.0                    -1084.0    ...
# 1670196             NaN            NaN                        NaN    ...
# 1670197             NaN            NaN                        NaN    ...
# 1670198          -684.0         -564.0                     -354.0    ...
# 1670199        365243.0       365243.0                      174.0    ...
# 1670200         -2409.0        -1719.0                    -1719.0    ...
# 1670201         -1697.0        -1367.0                    -1367.0    ...
# 1670202          -948.0         -858.0                     -798.0    ...
# 1670203             NaN            NaN                        NaN    ...
# 1670204             NaN            NaN                        NaN    ...
# 1670205             NaN            NaN                        NaN    ...
# 1670206         -1802.0        -1112.0                    -1112.0    ...
# 1670207             NaN            NaN                        NaN    ...
# 1670208         -1249.0         -919.0                     -199.0    ...
# 1670209          -508.0         -358.0                      362.0    ...
# 1670210         -1604.0        -1304.0                    -1274.0    ...
# 1670211         -1457.0        -1187.0                    -1187.0    ...
# 1670212         -1155.0         -825.0                     -825.0    ...
# 1670213         -1163.0         -443.0                      247.0    ...
#
#          NAME_SELLER_INDUSTRY NAME_YIELD_GROUP NFLAG_INSURED_ON_APPROVAL  \
# 0                Connectivity           middle                       0.0
# 1                         XNA       low_action                       1.0
# 2                         XNA             high                       1.0
# 3                         XNA           middle                       1.0
# 4                         XNA             high                       NaN
# 5                         XNA       low_normal                       1.0
# 6                         XNA              XNA                       NaN
# 7                         XNA              XNA                       NaN
# 8                         XNA              XNA                       NaN
# 9                         XNA              XNA                       NaN
# 10                        XNA       low_normal                       1.0
# 11                        XNA           middle                       1.0
# 12                        XNA             high                       1.0
# 13       Consumer electronics       low_action                       1.0
# 14       Consumer electronics           middle                       0.0
# 15                   Industry       low_normal                       0.0
# 16       Consumer electronics             high                       0.0
# 17                        XNA              XNA                       0.0
# 18                        XNA       low_normal                       NaN
# 19                        XNA             high                       NaN
# 20                        XNA       low_normal                       NaN
# 21                        XNA       low_normal                       1.0
# 22                        XNA              XNA                       NaN
# 23                        XNA       low_normal                       NaN
# 24                        XNA              XNA                       NaN
# 25                        XNA       low_normal                       1.0
# 26       Consumer electronics           middle                       0.0
# 27       Consumer electronics             high                       1.0
# 28               Connectivity       low_normal                       0.0
# 29                        XNA              XNA                       NaN
# ...                       ...              ...                       ...
# 1670184                   XNA       low_normal                       NaN
# 1670185                   XNA           middle                       NaN
# 1670186                   XNA              XNA                       NaN
# 1670187                   XNA              XNA                       NaN
# 1670188                   XNA       low_normal                       NaN
# 1670189                   XNA       low_normal                       NaN
# 1670190                   XNA              XNA                       NaN
# 1670191  Consumer electronics              XNA                       NaN
# 1670192                   XNA              XNA                       0.0
# 1670193                   XNA              XNA                       NaN
# 1670194                   XNA       low_normal                       1.0
# 1670195             Furniture       low_normal                       0.0
# 1670196          Connectivity              XNA                       NaN
# 1670197          Construction           middle                       NaN
# 1670198          Connectivity           middle                       0.0
# 1670199          Connectivity             high                       1.0
# 1670200  Consumer electronics             high                       1.0
# 1670201             Furniture             high                       0.0
# 1670202              Clothing           middle                       0.0
# 1670203          Connectivity              XNA                       NaN
# 1670204                   XNA           middle                       NaN
# 1670205                   XNA             high                       NaN
# 1670206                   XNA             high                       0.0
# 1670207                   XNA             high                       NaN
# 1670208                   XNA           middle                       1.0
# 1670209             Furniture       low_normal                       0.0
# 1670210             Furniture           middle                       0.0
# 1670211  Consumer electronics       low_normal                       0.0
# 1670212                   XNA       low_normal                       1.0
# 1670213                   XNA           middle                       0.0
#
#         NFLAG_LAST_APPL_IN_DAY             PRODUCT_COMBINATION  \
# 0                            1        POS mobile with interest
# 1                            1                Cash X-Sell: low
# 2                            1               Cash X-Sell: high
# 3                            1             Cash X-Sell: middle
# 4                            1               Cash Street: high
# 5                            1                Cash X-Sell: low
# 6                            1                            Cash
# 7                            1                            Cash
# 8                            1                            Cash
# 9                            1                            Cash
# 10                           1                Cash X-Sell: low
# 11                           1             Cash X-Sell: middle
# 12                           1               Cash X-Sell: high
# 13                           1  POS household without interest
# 14                           1     POS household with interest
# 15                           1         POS other with interest
# 16                           1     POS household with interest
# 17                           1                     Card X-Sell
# 18                           1                Cash X-Sell: low
# 19                           1               Cash Street: high
# 20                           1                Cash X-Sell: low
# 21                           1                Cash X-Sell: low
# 22                           1                            Cash
# 23                           1                Cash X-Sell: low
# 24                           1                            Cash
# 25                           1                Cash X-Sell: low
# 26                           1             Cash X-Sell: middle
# 27                           1               Cash X-Sell: high
# 28                           1        POS mobile with interest
# 29                           1                            Cash
# ...                        ...                             ...
# 1670184                      1                Cash X-Sell: low
# 1670185                      1             Cash Street: middle
# 1670186                      1                            Cash
# 1670187                      1                            Cash
# 1670188                      1                Cash X-Sell: low
# 1670189                      1                Cash Street: low
# 1670190                      1                            Cash
# 1670191                      1                     Card Street
# 1670192                      1                     Card X-Sell
# 1670193                      1                     Card Street
# 1670194                      1                Cash X-Sell: low
# 1670195                      1      POS industry with interest
# 1670196                      1        POS mobile with interest
# 1670197                      1      POS industry with interest
# 1670198                      1        POS mobile with interest
# 1670199                      1        POS mobile with interest
# 1670200                      1               Cash Street: high
# 1670201                      1      POS industry with interest
# 1670202                      1      POS industry with interest
# 1670203                      1        POS mobile with interest
# 1670204                      1             Cash X-Sell: middle
# 1670205                      1               Cash Street: high
# 1670206                      1               Cash Street: high
# 1670207                      1               Cash Street: high
# 1670208                      1             Cash X-Sell: middle
# 1670209                      1      POS industry with interest
# 1670210                      1      POS industry with interest
# 1670211                      1     POS household with interest
# 1670212                      1                Cash X-Sell: low
# 1670213                      1             Cash X-Sell: middle
#
#         RATE_DOWN_PAYMENT RATE_INTEREST_PRIMARY RATE_INTEREST_PRIVILEGED  \
# 0                0.000000              0.182832                 0.867336
# 1                     NaN                   NaN                      NaN
# 2                     NaN                   NaN                      NaN
# 3                     NaN                   NaN                      NaN
# 4                     NaN                   NaN                      NaN
# 5                     NaN                   NaN                      NaN
# 6                     NaN                   NaN                      NaN
# 7                     NaN                   NaN                      NaN
# 8                     NaN                   NaN                      NaN
# 9                     NaN                   NaN                      NaN
# 10                    NaN                   NaN                      NaN
# 11                    NaN                   NaN                      NaN
# 12                    NaN                   NaN                      NaN
# 13               0.000000                   NaN                      NaN
# 14               0.000000                   NaN                      NaN
# 15               0.103971                   NaN                      NaN
# 16               0.051324                   NaN                      NaN
# 17                    NaN                   NaN                      NaN
# 18                    NaN                   NaN                      NaN
# 19                    NaN                   NaN                      NaN
# 20                    NaN                   NaN                      NaN
# 21                    NaN                   NaN                      NaN
# 22                    NaN                   NaN                      NaN
# 23                    NaN                   NaN                      NaN
# 24                    NaN                   NaN                      NaN
# 25                    NaN                   NaN                      NaN
# 26                    NaN                   NaN                      NaN
# 27               0.000000                   NaN                      NaN
# 28               0.131374                   NaN                      NaN
# 29                    NaN                   NaN                      NaN
# ...                   ...                   ...                      ...
# 1670184               NaN                   NaN                      NaN
# 1670185               NaN                   NaN                      NaN
# 1670186               NaN                   NaN                      NaN
# 1670187               NaN                   NaN                      NaN
# 1670188               NaN                   NaN                      NaN
# 1670189               NaN                   NaN                      NaN
# 1670190               NaN                   NaN                      NaN
# 1670191               NaN                   NaN                      NaN
# 1670192               NaN                   NaN                      NaN
# 1670193               NaN                   NaN                      NaN
# 1670194               NaN                   NaN                      NaN
# 1670195          0.108909                   NaN                      NaN
# 1670196          0.000000                   NaN                      NaN
# 1670197          0.000000                   NaN                      NaN
# 1670198          0.109081                   NaN                      NaN
# 1670199          0.000000                   NaN                      NaN
# 1670200          0.000000                   NaN                      NaN
# 1670201          0.044300                   NaN                      NaN
# 1670202          0.000000                   NaN                      NaN
# 1670203          0.000000                   NaN                      NaN
# 1670204               NaN                   NaN                      NaN
# 1670205               NaN                   NaN                      NaN
# 1670206          0.000000                   NaN                      NaN
# 1670207          0.000000                   NaN                      NaN
# 1670208               NaN                   NaN                      NaN
# 1670209          0.000000                   NaN                      NaN
# 1670210          0.340554                   NaN                      NaN
# 1670211          0.101401                   NaN                      NaN
# 1670212               NaN                   NaN                      NaN
# 1670213               NaN                   NaN                      NaN
#
#         SELLERPLACE_AREA SK_ID_PREV
# 0                     35    2030495
# 1                     -1    2802425
# 2                     -1    2523466
# 3                     -1    2819243
# 4                     -1    1784265
# 5                     -1    1383531
# 6                     -1    2315218
# 7                     -1    1656711
# 8                     -1    2367563
# 9                     -1    2579447
# 10                    -1    1715995
# 11                    -1    2257824
# 12                    -1    2330894
# 13                   200    1397919
# 14                    83    2273188
# 15                   130    1232483
# 16                   130    2163253
# 17                     6    1285768
# 18                     6    2393109
# 19                     6    1173070
# 20                    -1    1506815
# 21                    -1    1182516
# 22                    -1    1172842
# 23                    -1    1172937
# 24                    -1    1555330
# 25                    -1    1543131
# 26                    -1    2536650
# 27                    -1    1676258
# 28                    61    2075578
# 29                    -1    1583704
# ...                  ...        ...
# 1670184               -1    1458393
# 1670185               -1    2815037
# 1670186               -1    1433968
# 1670187               -1    1971628
# 1670188               -1    1713281
# 1670189               -1    2406354
# 1670190               -1    2381880
# 1670191              150    1755809
# 1670192               10    2101747
# 1670193               10    1120445
# 1670194               10    2101748
# 1670195               80    2561520
# 1670196               96    1662123
# 1670197              673    1854636
# 1670198              100    1540903
# 1670199              100    1077969
# 1670200               -1    1024416
# 1670201              220    1028905
# 1670202               20    2205099
# 1670203              106    2844282
# 1670204              100    1407146
# 1670205              100    2815130
# 1670206              100    2459206
# 1670207              100    1662353
# 1670208              100    1556789
# 1670209               43    2300464
# 1670210               43    2357031
# 1670211             1370    2659632
# 1670212               -1    2785582
# 1670213               -1    2418762
#
# [1670214 rows x 29 columns]
